# %%
import numpy as np
# Out:
# Running cells with 'Python 3.13.2' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Sanskrati/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
arr_id = np.array([1,,2,3,4,5]) 
print("id array" )
